# %%
import pandas as pd   
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/mohammad/Desktop/Quantitave-Trading-/Data/APPL_closing.csv')

# %%
df
# Out:
#         close
# 0     132.045
# 1     131.780
# 2     130.280
# 3     130.535
# 4     129.960
# ...       ...
# 1253  314.960
# 1254  313.140
# 1255  319.230
# 1256  316.850
# 1257  318.890
#
# [1258 rows x 1 columns]

# %%
plt.plot(df)

# %%
#make some stat about data 
# Calculate the mean of the data
mean = df.mean()

# Calculate the standard deviation of the data
std = df.std()

# Calculate the maximum value in the data
max_value = df.max()

# Calculate the minimum value in the data
min_value = df.min()

# Print the statistics
print("Mean:", mean)
print("Standard Deviation:", std)
print("Maximum Value:", max_value)
print("Minimum Value:", min_value)
# Out:
# Mean: close    167.723998
# dtype: float64
# Standard Deviation: close    56.850796
# dtype: float64
# Maximum Value: close    327.2
# dtype: float64
# Minimum Value: close    90.34
# dtype: float64
